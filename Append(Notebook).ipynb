# %%
import pandas as pd
from access_onedrive import create_onedrive_directdownload
   
data_files = ['https://1drv.ms/x/s!AsCp_kE1E5Md510L7cgZfxy_ifCq?e=bNj2eY', 'https://1drv.ms/x/s!AsCp_kE1E5Md6TUUuL5DtjrFTggO?e=xA3jaE', 'https://1drv.ms/x/s!AsCp_kE1E5Md6TSDbgcW_MFQzySB?e=oWsFUm']

# %%
data = pd.DataFrame()
for file in range(len(data_files)):
    data.append(pd.read_excel(create_onedrive_directdownload(data_files[file])))
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_19796\1131516197.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data.append(pd.read_excel(create_onedrive_directdownload(file)))
# C:\Users\Hp\AppData\Local\Temp\ipykernel_19796\1131516197.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data.append(pd.read_excel(create_onedrive_directdownload(file)))
# C:\Users\Hp\AppData\Local\Temp\ipykernel_19796\1131516197.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data.append(pd.read_excel(create_onedrive_directdownload(file)))

# %%
data.append(pd.read_excel(create_onedrive_directdownload(data_files[0])))
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_19796\2144387018.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data.append(pd.read_excel(create_onedrive_directdownload(data_files[0])))
#         Unnamed: 0      A       ER_NO GENDER     CITY             AREA  \
# 0                0      1  E001467306      M  KARACHI  Gulshan-e-Iqbal
# 1                1      2  E001461259      M  KARACHI       Azam Basti
# 2                2      3  E001453586      F  KARACHI          Korangi
# 3                3      4  E001455608      F  KARACHI           Landhi
# 4                4      5  E001467427      F    Badin      KHOSKI ROAD
# ...            ...    ...         ...    ...      ...              ...
# 137415      137415  20105  E001547651      F  KARACHI    Bhains colony
# 137416      137416  20108  E001554170      F  KARACHI          Korangi
# 137417      137417  20109  E001549164      M  KARACHI            Sadar
# 137418      137418  20110  E001549787      F  KARACHI          Korangi
# 137419      137419  20111  E001547209      M  KARACHI    Ibrahim Hydri
#
#         AGE_YEARS MR_DOB     TRIAGE_DATETIME  \
# 0         17.0037  37375 2019-04-30 14:12:51
# 1         19.0006  36635 2019-04-19 23:28:58
# 2         25.8453  34121 2019-04-05 23:43:38
# 3         60.0020  21649 2019-04-09 15:30:03
# 4         25.4750  34281 2019-04-30 17:36:57
# ...           ...    ...                 ...
# 137415    53.9943  24001 2019-09-14 09:53:17
# 137416    30.0010  32774 2019-09-23 21:09:38
# 137417    21.3378  35931 2019-09-16 12:53:05
# 137418    29.2609  33038 2019-09-17 12:59:53
# 137419    50.6987  25204 2019-09-13 16:28:26
#
#                               TRIAGECOMPLAINT  ... month  day  hour  \
# 0                            Bites and stings  ...     4   30    14
# 1                               Limb problems  ...     4   19    23
# 2                                Unwell adult  ...     4    6     0
# 3                               Limb problems  ...     4    9    17
# 4                                Unwell adult  ...     4   30    17
# ...                                       ...  ...   ...  ...   ...
# 137415                   Limb problems,Wounds  ...     9   14    10
# 137416                  Headache,Unwell adult  ...     9   23    21
# 137417  Abdominal pain in adults,Unwell adult  ...     9   16    15
# 137418                               Headache  ...     9   17    13
# 137419          Facial problems,Limb problems  ...     9   13    16
#
#          lostriage        losED loshospital    shift           new_mr  \
# 0         0.183333  1440.000000         NaN  Shift 2  221019006472399
# 1         7.983333          NaN         NaN  Shift 1  971019005957160
# 2        31.816667  1440.000000         NaN  Shift 1  831017028941466
# 3       134.200000  1440.000000         NaN  Shift 2  491019005437584
# 4         6.666667  1440.000000         NaN  Shift 2  431018008276111
# ...            ...          ...         ...      ...              ...
# 137415   26.300000   613.716667         NaN  Shift 2  151015013058550
# 137416    2.216667   168.066667         NaN  Shift 1  671019014052499
# 137417  149.133333   345.250000         NaN  Shift 2  635018000010214
# 137418   21.750000   127.766667         NaN  Shift 2  511016008333764
# 137419    1.933333   257.350000         NaN  Shift 2  381019013406075
#
#           new_doctor_name    new_nurse_name
# 0             Jason Brown       Rachel Bell
# 1             Jacob Stein       Rachel Bell
# 2             Jason Brown       Rachel Bell
# 3              Cody Brown       Rachel Bell
# 4             Jason Brown       Rachel Bell
# ...                   ...               ...
# 137415  Cynthia Gutierrez       Lisa Thomas
# 137416   Jonathan Francis    Margaret Yates
# 137417  Cynthia Gutierrez    Regina Johnson
# 137418   Andrew Patterson  Patricia Rowland
# 137419       Joseph Banks     Brianna Riggs
#
# [137420 rows x 46 columns]

# %%
print(data)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#write appended data to one drive
#clean new data 
#append new data to old data and save it as old data
#pass the new data for analysis

#remove duplicate rows in indus clean

# %%
df.concat()
